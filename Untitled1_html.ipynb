# %% [markdown]
# <a href="https://colab.research.google.com/github/ShreyasT123/ShreyasT123/blob/main/Untitled1_html.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
<!DOCTYPE html>
<html>
<head><title>hello
</title
</head>
</html>
# Out:
#   File "<ipython-input-3-fcdc4dab0c9f>", line 1
#     <!DOCTYPE html>
#     ^
# SyntaxError: invalid syntax
